# %%
# from google.colab import drive
# drive.mount('/content/drive')
# %cd /content/drive/MyDrive/Research/NLP/Project/
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/Research/NLP/Project

# %%
#For subtask 1A
# !python scripts/baselines/task.py \
  --train-file-path data/sub-task-1a/train.tsv \
  --dev-file-path data/sub-task-1a/dev.tsv \
  --subtask 1A
# Out:
# INFO : Checking format of prediction file...
# INFO : File passed format checker!
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# INFO : Majority Baseline: Accuracy=0.5639	Precision=0.3180	Recall=0.5639	F1=0.5639
# INFO : Checking format of prediction file...
# INFO : File passed format checker!
# INFO : Random Baseline: Accuracy=0.1398	Precision=0.3555	Recall=0.1398	F1=0.1398
# INFO : Checking format of prediction file...
# INFO : File passed format checker!
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# ...

# %%
#For subtask 1B
# !python scripts/baselines/task.py \
  --train-file-path data/sub-task-1b/train.tsv \
  --dev-file-path data/sub-task-1b/dev.tsv \
  --subtask 1B
# Out:
# INFO : Checking format of prediction file...
# INFO : File passed format checker!
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# INFO : Majority Baseline: Accuracy=0.5747	Precision=0.3302	Recall=0.5747	F1=0.5747
# INFO : Checking format of prediction file...
# INFO : File passed format checker!
# INFO : Random Baseline: Accuracy=0.2222	Precision=0.3890	Recall=0.2222	F1=0.2222
# INFO : Checking format of prediction file...
# INFO : File passed format checker!
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# ...

# %%
#For subtask 1C
# !python scripts/baselines/task.py \
  --train-file-path data/sub-task-1c/train.tsv \
  --dev-file-path data/sub-task-1c/dev.tsv \
  --subtask 1C
# Out:
# INFO : Checking format of prediction file...
# INFO : File passed format checker!
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# ...
